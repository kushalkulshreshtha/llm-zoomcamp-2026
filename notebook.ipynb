# %%
print(123)
# Out:
# 123

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
def llm(prompt):
    response = openai_client.responses.create(
        model="gpt-5.4-mini",
        input=prompt
    )
    return response.output_text

# %%
question = "I just discovered the course. Can I join now?"
answer = llm(question)
print(answer)
# Out:
# Yes — if the course is still open and you meet any registration requirements, you can usually join now.
#
# A few things to check:
# - **Enrollment status:** Is registration still open?
# - **Start date:** Has the course already begun?
# - **Late access:** Some courses allow late joining, but you may have missed earlier materials.
# - **Approval/prerequisites:** Some courses require permission or prior experience.
#
# If you want, I can help you draft a quick message to the instructor or course admin asking about late enrollment.

# %%
import requests

docs_url = "https://datatalks.club/faq/json/courses.json"
response = requests.get(docs_url)
courses_raw = response.json()

# %%
documents = []
url_prefix = "https://datatalks.club/faq"

for course in courses_raw:
    course_url = f"""{url_prefix}{course["path"]}"""

    course_response = requests.get(course_url)
    course_response.raise_for_status()
    course_data = course_response.json()

    documents.extend(course_data)

len(documents)
# Out:
# 1350
